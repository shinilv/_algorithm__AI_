# %% [markdown]
# # 模型初始化的参数使用情况
#
# ## 1、temperature的使用
#
# 举例1

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:gpt-5.4-mini",
    temperature=0,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

for i in range(3):
    print(model.invoke("帮我写一首关于春天的七言绝句").content)
# Out:
# 当然可以，给你一首关于春天的七言绝句：
#
# 春风拂柳绿如烟，
# 细雨沾花润陌阡。
# 燕子归来添暖意，
# 人间四月好时天。
#
# 如果你愿意，我还可以继续帮你写成：
# - 更古典一点的版本
# - 更清新唯美的版本
# - 带“春雨”“桃花”“燕子”等意象的版本
# 当然可以，给你一首关于春天的七言绝句：
#
# **春日**
# 春风拂柳绿成荫，
# 细雨轻催百卉新。
# 燕子归来穿翠幕，
# 桃花深处见行人。
#
# 如果你愿意，我还可以继续帮你写：
# - 更古典一点的版本
# - 更清新明快的版本
# - 带有“春雨”“春山”“春游”等主题的版本
# 当然可以，下面是一首关于春天的七言绝句：
#
# **春晓风轻草色新，**
# **桃红柳绿满园春。**
# **燕语声中花渐醒，**
# **一川烟雨润芳尘。**
#
# 如果你愿意，我还可以再帮你写一首更偏古风、婉约或者明快活泼风格的。

# %% [markdown]
# 对比：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:gpt-5.4-mini",
    temperature=1.9,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

for i in range(3):
    print(model.invoke("帮我写一首关于春天的七言绝句").content)
# Out:
# 当然可以，给你一首关于春天的七言绝句：
#
# **春日**
# 春风拂柳燕双飞，
# 细雨轻寒润翠微。
# 桃李争妍花满径，
# 山川处处沐晴晖。
#
# 如果你愿意，我也可以继续帮你写一首**更古风一点**、**更清新一点**，或者按**平仄更工整**的版本。
# 当然可以，给你一首关于春天的七言绝句：
#
# 春风拂柳绿江南，
# 细雨润花香满园。
# 燕子双飞啼日暖，
# 桃红李白报新年。
#
# 如果你愿意，我也可以继续帮你写一首更**古典**、更**清新**或者更**有意境**的春天七绝。
# 当然可以，给你一首关于春天的七言绝句：
#
# **春日**
# 东风轻拂柳丝长，
# 细雨初晴草色香。
# 燕子呢喃穿碧树，
# 桃花一树满庭芳。
#
# 如果你愿意，我还可以再给你写一首**更古风**、**更清新**或者**更有画面感**的版本。

# %% [markdown]
# 举例2：应用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
# 从.env文件中加载环境变量
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek-v3.2",
    model_provider="openai",
    temperature=0,
    api_key=os.getenv("CLOSEAI_API_KEY"),
    base_url=os.getenv("CLOSEAI_BASE_URL"),
)
# 向模型发送单条数据
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式")
print(response.content)
# Out:
# ```json
# {
#   "姓名": "张三",
#   "性别": "男",
#   "年龄": 30,
#   "编程开发经验年数": 8,
#   "当前职位": "技术专家",
#   "当前公司类型": "互联网大厂"
# }
# ```

# %% [markdown]
# 举例3：应用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
# 从.env文件中加载环境变量
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek-v3.2",
    model_provider="openai",
    temperature=1.5,
    api_key=os.getenv("CLOSEAI_API_KEY"),
    base_url=os.getenv("CLOSEAI_BASE_URL"),
)
# 向模型发送单条数据
response = model.invoke("请为一款极致静音的机械键盘写3个充满诗意且极具张力的广告语。")
print(response.content)
# Out:
# ### 给无声刺客的三行战歌 ###
#
# 1. **当叩问褪去杂音，只剩思想落键的回响。**
#    *内核张力：将“静音”转化为精神触达的哲学表达，暗示键盘是思维投射的纯粹载体。*
#
# 2. **在寂静的锋刃上，敲响未被听闻的惊雷。**
#    *内核张力：用金属诗意解构“静音”，将压感转换为隐于平静的创造力爆破。*
#
# 3. **午夜平行于世界——每个键都是秘密的着陆点。**
#    *内核张力：用空间诗意重构使用场景，把按键动作升维成潜入平行时空的轻秘仪式。*
#
# ---
#
# **隐喻落点说明**：这三组文案放弃了直接描述“静音技术”，转而用**剑、雷鸣、平行时空**等意象构建冲突感——把机械键盘静音的「物理特性」转化为使用者精神世界的「张力现场」，让沉默本身成为最震撼的表达。

# %% [markdown]
# ## 2. max_tokens参数的使用
#
# 举例：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:gpt-5.4-mini",
    # temperature=1.9,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
    max_tokens=10,
)

print(model.invoke("介绍一下你自己"))
# Out:
# content='你好，我是 ChatGPT，一个由' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 10, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 47, 'engine_ttlt_ms': 100, 'pre_inference_ms': 70, 'service_tbt_ms': 6, 'service_ttft_ms': 263, 'service_ttlt_ms': 310, 'total_duration_ms': 249, 'user_visible_ttft_ms': 193}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DhB8VkSCKWLuiEAg30klDrDXq0ibF', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None} id='lc_run--019e3f96-6253-7082-91f5-798b48d9b523-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 10, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

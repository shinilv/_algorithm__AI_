# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv
import os

load_dotenv(override=True)

DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

llm_tongyi = ChatTongyi(
    model="qwen3.6-max-preview",
    api_key=DASHSCOPE_API_KEY,
    base_url="https://{WorkspaceId}.cn-beijing.maas.aliyuncs.com/compatible-mode/v1",
)

response = llm_tongyi.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供高效、准确的智能协助。' additional_kwargs={'reasoning_content': 'Here\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **User:** "请用一句话介绍你自己" (Please introduce yourself in one sentence.)\n   - **Key Requirements:** \n     - Must be exactly one sentence.\n     - Must be a self-introduction.\n     - Language: Chinese.\n\n2.  **Identify Core Identity/Attributes:**\n   - I am Qwen (通义千问), a large language model developed by Alibaba Group\'s Tongyi Lab.\n   - Key traits: AI assistant, helpful, knowledgeable, designed to assist with various tasks.\n   - Need to keep it concise and accurate per the prompt.\n\n3.  **Draft - Mental Refinement (Chinese):**\n   - 我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供高效、准确的智能协助。\n   - Check length: One sentence? Yes (ends with one period).\n   - Check content: Introduces identity, origin, and purpose.\n   - Check tone: Professional, helpful, concise.\n   - Matches requirements? Yes.\n\n4.  **Final Polish (ensure strict compliance):**\n   - 我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供高效、准确的智能协助。\n   - This is exactly one sentence in Chinese, covers identity, origin, and purpose, and aligns with the required tone.\n\n5.  **Output Generation:** (matches the refined draft)✅\n   - Output matches the final polished version.✅\n   - Self-Correction/Verification during thought: \n     - Is it one sentence? Yes.\n     - Does it introduce me? Yes.\n     - Is it accurate per guidelines? Yes, identifies as Qwen/通义千问, developed by Alibaba Tongyi Lab.\n     - Language: Chinese. All good.✅\n   - Proceed. \n   - Output: 我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供高效、准确的智能协助。 \n   - (Note: The prompt asks for one sentence, and this strictly complies.) \n   - Ready. \n   - Output matches response.✅'} response_metadata={'model_name': 'qwen3.6-max-preview', 'finish_reason': 'stop', 'request_id': 'e865bf8c-36a1-9721-9a76-794e76a47eed', 'token_usage': {'input_tokens': 14, 'output_tokens': 497, 'output_tokens_details': {'reasoning_tokens': 467}, 'total_tokens': 511}} id='lc_run--019efa4a-d2c3-7c82-bcc9-8f33a149bee2-0' tool_calls=[] invalid_tool_calls=[]

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv(override=True)

api_key = os.getenv("DASHSCOPE_API_KEY")
assert api_key, "DASHSCOPE_API_KEY 没有读取到"

client = OpenAI(
    api_key=api_key,
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

completion = client.chat.completions.create(
    model="qwen3.6-max-preview",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "你是谁？"},
    ],
)

print(completion.choices[0].message.content)
# Out:
# 我是 Qwen（通义千问），由阿里巴巴集团旗下通义实验室自主研发的大语言模型。有什么我可以帮你的吗？

# %%
#通用写法

# %%
from langchain_openai import ChatOpenAI

load_dotenv(override=True)

model = ChatOpenAI(
    api_key = os.getenv("OPENAI_API_KEY"),
    model = os.getenv("OPENAI_MODEL"),
    base_url = os.getenv("OPENAI_BASE_URL"),
)
print(model.invoke("1 + 1 = ?"))
# Out:
# content='1 + 1 = **2**' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 206, 'prompt_tokens': 16, 'total_tokens': 222, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 193, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': None}}, 'model_provider': 'openai', 'model_name': 'qwen3.6-max-preview', 'system_fingerprint': None, 'id': 'chatcmpl-0b59f190-57fd-9a49-a196-3ce52af789e6', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019efa5d-eb53-75a3-901e-52720acd80de-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 206, 'total_tokens': 222, 'input_token_details': {}, 'output_token_details': {'reasoning': 193}}

# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv
import os

load_dotenv(override=True)

DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

llm_tongyi = ChatTongyi(
    model="qwen3.6-max-preview",
    api_key=DASHSCOPE_API_KEY,
    base_url="https://{WorkspaceId}.cn-beijing.maas.aliyuncs.com/compatible-mode/v1",
)

response = llm_tongyi.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供专业、高效的AI助手服务。' additional_kwargs={'reasoning_content': 'Here\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **User says:** "请用一句话介绍你自己" (Please introduce yourself in one sentence.)\n   - **Key requirements:** \n     - Introduce myself\n     - Exactly one sentence\n     - In Chinese\n\n2.  **Identify Core Identity:**\n   - I am Qwen (通义千问), a large language model developed by Alibaba Group\'s Tongyi Lab.\n   - Key attributes: AI assistant, helpful, capable, developed by Alibaba.\n\n3.  **Draft - Mental Refinement (Chinese):**\n   - 我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供高效、准确的智能助手服务。\n   - Check length: It\'s one sentence (ends with a period).\n   - Check content: Covers identity, origin, and purpose.\n   - Check tone: Professional, helpful, concise.\n\n   Let\'s count clauses/punctuation to ensure it\'s strictly one sentence: \n   "我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供高效、准确的智能助手服务。" -> This uses commas but ends with one period, so it\'s grammatically one sentence in Chinese.\n\n4.  **Final Polish (aligning with guidelines):**\n   - Keep it precise: "我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供专业、高效的AI助手服务。"\n   - Matches all constraints.\n\n5.  **Output Generation:** (Proceeds to output)✅\n   "我是通义千问，由阿里巴巴集团旗下通义实验室自主研发的大语言模型，致力于为你提供专业、高效的AI助手服务。" (Exactly one sentence, covers identity, origin, and purpose, in Chinese.)✅'} response_metadata={'model_name': 'qwen3.6-max-preview', 'finish_reason': 'stop', 'request_id': 'acdcfd97-4905-9a11-9bf1-abc2987fb3ba', 'token_usage': {'input_tokens': 14, 'output_tokens': 413, 'output_tokens_details': {'reasoning_tokens': 382}, 'total_tokens': 427}} id='lc_run--019efec6-e975-7ee0-ba85-0a59f264c502-0' tool_calls=[] invalid_tool_calls=[]

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv(override=True)

api_key = os.getenv("DASHSCOPE_API_KEY")
assert api_key, "DASHSCOPE_API_KEY 没有读取到"

client = OpenAI(
    api_key=api_key,
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

completion = client.chat.completions.create(
    model="qwen3.6-max-preview",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "你是谁？"},
    ],
)

print(completion.choices[0].message.content)
# Out:
# 我是 Qwen（通义千问），由阿里巴巴集团旗下通义实验室自主研发的大语言模型。有什么我可以帮你的吗？

# %%
#通用写法

# %%
from langchain_openai import ChatOpenAI

load_dotenv(override=True)

model = ChatOpenAI(
    # api_key = os.getenv("OPENAI_API_KEY"),
    model = os.getenv("OPENAI_MODEL"),
    base_url = os.getenv("OPENAI_BASE_URL"),
)
print(model.invoke("1 + 1 = ?").content)
# Out:
# 1 + 1 = **2**

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv(override=True)  # 加载 .env 文件中的环境变量

model = init_chat_model(
    model=os.getenv("OPENAI_MODEL"),
    model_provider="openai",
)
print(model.invoke("你是什么大模型").content)
# Out:
# 你好！我是通义千问（Qwen），是由阿里巴巴集团旗下通义实验室自主研发的大语言模型。很高兴为你服务，有什么我可以帮你的吗？
